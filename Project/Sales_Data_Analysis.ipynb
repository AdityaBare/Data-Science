# %%
import pandas as pd
import numpy as np

df = pd.read_csv("sales_data_25000.csv")

# %% [markdown]
# # Understanding data

# %%
print("Shape : ",df.shape)
print("Column names :",df.columns)
# Out:
# Shape :  (25075, 13)
# Column names : Index(['Order ID', 'Order Date', 'Customer ID', 'Customer Type', 'Product',
#        'Category', 'Region', 'City', 'Quantity', 'Price Each', 'Discount',
#        'Sales', 'Payment Mode'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25075 entries, 0 to 25074
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       25075 non-null  object
#  1   Order Date     25075 non-null  object
#  2   Customer ID    25075 non-null  object
#  3   Customer Type  25040 non-null  object
#  4   Product        25075 non-null  object
#  5   Category       25075 non-null  object
#  6   Region         25075 non-null  object
#  7   City           25040 non-null  object
#  8   Quantity       25075 non-null  int64
#  9   Price Each     25075 non-null  float64
#  10  Discount       25075 non-null  float64
#  11  Sales          25075 non-null  float64
#  12  Payment Mode   25045 non-null  object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 2.5+ MB

# %%
df.head(10)
# Out:
#     Order ID  Order Date Customer ID Customer Type       Product  \
# 0  ORD112908  2024-10-16   CUST11433           New     Bookshelf
# 1  ORD114592  2025-08-15   CUST11178       Regular       Pen Set
# 2  ORD111761  2025-09-28   CUST10146       Regular  Coffee Maker
# 3  ORD114241  2025-09-26   CUST11112       Regular       Pen Set
# 4  ORD108748  2024-03-09   CUST11484       Premium     Air Fryer
# 5  ORD112116  2025-10-07   CUST11540       Regular        Laptop
# 6  ORD101427  2025-01-25   CUST10382       Regular         Jeans
# 7  ORD104203  2025-12-28   CUST11806       Regular          Desk
# 8  ORD124493  2024-02-20   CUST10161       Premium      Keyboard
# 9  ORD114790  2024-08-11   CUST10676       Regular       Monitor
#
#           Category   Region         City  Quantity  Price Each  Discount  \
# 0        Furniture    North        Delhi         6     6639.25      0.10
# 1       Stationery     West   Aurangabad         2      193.78      0.03
# 2  Home Appliances     West         Pune         5     4122.21      0.05
# 3       Stationery    South      Chennai         2      169.92      0.03
# 4  Home Appliances    North        Delhi         5     6349.53      0.10
# 5      Electronics    North        Delhi         6    57899.59      0.08
# 6          Fashion     East  Bhubaneswar         1     1863.47      0.03
# 7        Furniture  Central       Nagpur         2    12112.40      0.05
# 8      Electronics     East        Patna         3     1339.69      0.15
# 9      Electronics    South        Kochi         3    11154.12      0.03
#
#        Sales Payment Mode
# 0   35851.95  Net Banking
# 1     375.93   Debit Card
# 2   19580.50          UPI
# 3     329.64          UPI
# 4   28572.88  Credit Card
# 5  319605.74          UPI
# 6    1807.57  Credit Card
# 7   23013.56   Debit Card
# 8    3416.21  Net Banking
# 9   32458.49          UPI

# %%
df.tail(10)

# %% [markdown]
# # Level 2 — Data Cleaning

# %%
df.isnull().sum()

# %% [markdown]
# * Find Duplicate rows

# %%
print(df.duplicated().sum(),'\n')
df.duplicated()

# %%
df[df.duplicated()]

# %% [markdown]
# * Drop duplicate rows

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Unique products

# %%
df['Product'].unique()
# Out:
# array(['Bookshelf', 'Pen Set', 'Coffee Maker', 'Air Fryer', 'Laptop',
#        'Jeans', 'Desk', 'Keyboard', 'Monitor', 'Printer', 'Tablet',
#        'Smartphone', 'Backpack', 'T-Shirt', 'Mixer Grinder', 'Mouse',
#        'Shoes', 'Blender', 'Headphones', 'Jacket', 'Desk Lamp',
#        'Water Bottle', 'Office Chair', 'Notebook'], dtype=object)

# %%
df['Customer ID'].unique()

# %%
df['Order Date'].head()

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.head()

# %%
df['Order Date'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['Quantity']<0, 'Quantity'].count()
# Out:
# 0

# %%
df.loc[df['Price Each']<0, 'Price Each'].count()
# Out:
# 0

# %%
df.shape
# Out:
# (25000, 13)

# %%
sales = df['Quantity']*df['Price Each']
df.loc[df['Sales']!=sales-sales*(1-df['Discount']) ,'Sales'].count()

# %%
df['Sales'] = sales-sales*df['Discount']

# %%
sales = df['Quantity']*df['Price Each']
df.loc[df['Sales']!=sales-sales*df['Discount'] ,'Sales'].count()
# Out:
# 0

# %%
df.isnull().sum()

# %%
df['Customer Type'] = np.where(df['Customer Type'].isnull(), 'Regular', df['Customer Type'])
# Another method
#df['Customer Type'].fillna('Regular' , inplace = True)

# %%
df.isnull().sum()

# %%
df.dropna(axis=0 , inplace=True)

# %%
df.shape
# Out:
# (24935, 13)

# %% [markdown]
# # Numpy operations

# %%
print("Mean :",np.mean(df['Sales']))
print("Median :",np.median(df['Sales']))
print("Max :",np.max(df['Sales']))
print("Min :",np.min(df['Sales']))
print("std :",np.std(df['Sales']))

# %% [markdown]
# # Filtering

# %%
df.loc[df['Sales']>1000 , ('Sales','Product')]

# %%
df.loc[(df['Quantity']>5) & (df['Sales']>500), 'Sales']

# %%
df.loc[df['City']== 'Mumbai','Sales']

# %%
df.loc[df['Order Date'].dt.year ==  2025]

# %%
df.nlargest(20,'Sales')

# df.sort_values(by='Sales, ascending = False).head(20)

# %% [markdown]
# * Sales by product

# %%
df.groupby('Product')['Sales'].sum().nlargest(1)

# %% [markdown]
# * Sales by category

# %%
df.groupby('Category')['Sales'].sum()

# %%
print("Best Performing")
best = df.groupby('Category')['Sales'].sum().nlargest(1)
best

# %% [markdown]
# # Sales by Region

# %%
df.groupby('Region')['Sales'].sum()
# Out:
# Region
# Central    3.365818e+07
# East       1.148183e+08
# North      1.394801e+08
# South      1.491949e+08
# West       1.458085e+08
# Name: Sales, dtype: float64

# %% [markdown]
# * Best Region

# %%
df.groupby('Region')['Sales'].sum().nlargest(1)

# %% [markdown]
# * Quantity Sold by product

# %%
df.groupby('Product')['Quantity'].sum()

# %% [markdown]
# * Category Average

# %%
df.groupby('Category')['Price Each'].mean()

# %% [markdown]
# # Sorting

# %% [markdown]
# * Sort products by total sales:

# %%
sort_product = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)

# %% [markdown]
# * Top 10 product by revenue.

# %%
sort_product.head(10)

# %% [markdown]
# * Bottom 10 product

# %%
sort_product.tail(10)

# %% [markdown]
# * Find the top 10 cities by sales.

# %%
df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

# %% [markdown]
# # Level 7 — Time-Series Analysis

# %% [markdown]
# * Add Column

# %%
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Month Name'] = df['Order Date'].dt.month_name()

# %%
df.head()

# %% [markdown]
# * Total sales by year

# %%
df.groupby('Year')['Sales'].sum()

# %% [markdown]
# * Total sales by month

# %%
sales_per_month = df.groupby('Month Name')['Sales'].sum()
sales_per_month

# %% [markdown]
# * Which Month has highest sales

# %%
sales_per_month.sort_values(ascending=False).head(1)

# %% [markdown]
# * Which Month has lowest sales.

# %%
sales_per_month.sort_values(ascending=True).head(1)

# %% [markdown]
# * Calculate monthly average sales

# %%
df.groupby('Month Name')['Sales'].mean()

# %% [markdown]
# * Find the best-performing year.

# %%
df.groupby('Year')['Sales'].sum().sort_values(ascending=False).nlargest(1)

# %% [markdown]
# # Level 8

# %%
pd.pivot_table(
    data=df,
    values='Sales',
    index='Product',
    columns='Region',
    aggfunc='sum'
)

# %%
#  Same but if diffrent form
df.groupby(['Region','Product'])['Sales'].sum()

# %% [markdown]
# * Region × Category

# %%
pd.pivot_table(
    data = df,
    values='Sales',
    index='Region',
    columns='Category',
    aggfunc='sum'
)

# %% [markdown]
# * Month × Category

# %%
pd.pivot_table(
    data=df,
    values='Sales',
    index='Month Name',
    columns='Category',
    aggfunc = 'sum'
    )

# %% [markdown]
# * Region × Payment Mode

# %%
pd.pivot_table(
    data=df,
    values='Quantity',
    index='Region',
    columns='Payment Mode',
    aggfunc='sum'
)
