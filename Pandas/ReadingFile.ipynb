# %% [markdown]
# # Reading Files In Pandas

# %% [markdown]
# 1. Import pandas and use reference variable as pd.

# %%
import pandas as pd

# %% [markdown]
# 2. Read data from csv file into a dataframe.
#     - \U → Start of a Unicode escape sequence (which causes an error)
#     - ues "r" before they path , then it treat path as raw string.
#     - or replace \ with \\.
#     - or use forward slashes /.

# %%
df = pd.read_csv(r"C:\Users\barea\Downloads\indian_employee_data.csv")
# Here are two types of file Utf or utf-8 (Support all language) and  latin (support only 256).

# %% [markdown]
# 3. Reading data from excel and json.

# %%
<!-- 
df = pd.read_json("fileName.json")
df = pd.read_excel("fileName.elsx")
 -->

# %% [markdown]
# 4. Reading data from cloud storage.
#     - gcsfs this library use to read data from cloud
