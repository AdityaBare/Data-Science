# %% [markdown]
# # Filling Missging Data

# %%
import pandas as pd

df2 = pd.read_csv(r"C:\Users\barea\OneDrive\Desktop\Data Science\Numpy\IndianEmployeeProject\indian_employee_data.csv")


data = {
    "Roll No.":[1,None,5,20],
    "Name":["Nilesh","Pranav","Aditya","Ram"],
    "Age":[20,19,None,20],
    'marks':[1,2,3,4],
    "Salary":[30000,25000,35000,None],
    "Date":["Mar 26","Feb 23","May 12",None]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    Roll No.    Name   Age  marks   Salary    Date
# 0       1.0  Nilesh  20.0      1  30000.0  Mar 26
# 1       NaN  Pranav  19.0      2  25000.0  Feb 23
# 2       5.0  Aditya   NaN      3  35000.0  May 12
# 3      20.0     Ram  20.0      4      NaN    None

# %% [markdown]
# 1. df.fillna(value, inplace=True)
#     * replace all none value in table with given value.

# %%
df.fillna(0,inplace = True)
print(df)
# Out:
#    Roll No.    Name   Age  marks   Salary    Date
# 0       1.0  Nilesh  20.0      1  30000.0  Mar 26
# 1       0.0  Pranav  19.0      2  25000.0  Feb 23
# 2       5.0  Aditya   0.0      3  35000.0  May 12
# 3      20.0     Ram  20.0      4      0.0       0

# %% [markdown]
# 2. df["col"].fillna(value , inplace = True)
#     * Replace perticular column none value with given value.

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
print(df)
# Out:
#    Roll No.    Name   Age  marks   Salary    Date
# 0       1.0  Nilesh  20.0      1  30000.0  Mar 26
# 1       0.0  Pranav  19.0      2  25000.0  Feb 23
# 2       5.0  Aditya   0.0      3  35000.0  May 12
# 3      20.0     Ram  20.0      4      0.0       0
# C:\Users\barea\AppData\Local\Temp\ipykernel_2488\3486977901.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
